# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
data = np.arange(10)

# %%
plt.plot(data)

# %%
fig = plt.fingure()
ax1 = fig.add_subplot(2,2,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-3b1a09c52cfd> in <module>
# ----> 1 fig = plt.fingure()
#       2 ax1 = fig.add_subplot(2,2,1)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'fingure'

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)

# %%
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
fig

# %%
plt.plot([1.5,3.5,-2,1.6])

# %%
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
fig

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

# %%
plt.plot([1.5,3.5,-2,1.6])

# %%
_ = ax1.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
ax2.scatter(np.arange(30),np.arange(30)+3*np.random.randn(30))

# %%
fig

# %%
plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
ax3 = plt.plot(np.random.randn(50).cumsum(),'k--')

# %%
fig

# %%
_=ax3.plot(np.random.randn(50).cumsum(),'k--')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-87846866b2bf> in <module>
# ----> 1 _=ax3.plot(np.random.randn(50).cumsum(),'k--')
#
# AttributeError: 'list' object has no attribute 'plot'

# %%
fig,axes=plt.subplots(2,3)

# %%
fig,axes=plt.subplots(2,2,sharex=True,sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(500),bins=50,color='k',alpha=0.5)
plt.subplots_adjust(wspace=0,hspace=0)

# %%
ax.plot(x,y,'g--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-f01af4f624a7> in <module>
# ----> 1 ax.plot(x,y,'g--')
#
# NameError: name 'ax' is not defined

# %%
from numpy.random import randn

# %%
plt.plot(randn(30).cumsum(),'ko--')

# %%
data = np.random.randn(30).cumsum()

# %%
plt.plot(data,'k--',label='Default')

# %%
plt.plot(data,'k--',drawstyle='steps-post',label='steps-post')

# %%
plt.legend(loc='best')
# Out:
# No handles with labels found to put in legend.

# %%
plt.legend(data,loc='best')

# %%
dig = plt.figure()
ax= fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())

# %%
dig

# %%
fig = plt.figure()
ax= fig.add_subplot(1,1,1)
ax.plot(np.random.randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0,250,500,750,1000])

# %%
labels = ax.set_xticklabels(['one','two','three','four','five'],rotatition=30,fontsize='small')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-a42e9d4379cd> in <module>
# ----> 1 labels = ax.set_xticklabels(['one','two','three','four','five'],rotatition=30,fontsize='small')
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\axes\_base.py in set_xticklabels(self, labels, fontdict, minor, **kwargs)
#    3420             kwargs.update(fontdict)
#    3421         ret = self.xaxis.set_ticklabels(labels,
# -> 3422                                         minor=minor, **kwargs)
#    3423         self.stale = True
#    3424         return ret
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\axis.py in set_ticklabels(self, ticklabels, minor, *args, **kwargs)
#    1682             # deal with label1
#    1683             tick.label1.set_text(tick_label)
# -> 1684             tick.label1.update(kwargs)
#    1685             # deal with label2
# ...

# %%
labels = ax.set_xticklabels(['one','two','three','four','five'],
                            rotation=30,fontsize='small')

# %%
ax.set_title('my first %matplotlib plot')
# Out:
# Text(0.5, 1.0, 'my first %matplotlib plot')

# %%
ax.set_xlabel('Stages')
# Out:
# Text(0.5, 3.1999999999999993, 'Stages')

# %%
fig

# %%
ax2= fig.add_subplot(1,2,1)

# %%
ax2.plot(randn(1000).cumsum(),'k',label='one')

# %%
ax2.plot(randn(1000).cumsum(),'k--',lable='two')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-0b7de2af562b> in <module>
# ----> 1 ax2.plot(randn(1000).cumsum(),'k--',lable='two')
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
# ...

# %%
ax2.plot(randn(1000).cumsum(),'k--',label='two')

# %%
ax2.plot(randn(1000).cumsum(),'k.',label='three')

# %%
ax2

# %%
fig

# %%
fig.add_subplot(2,2,2)

# %%
fig

# %%
ax2.legend(loc='best')

# %%
plt.legend(ax2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-49-144293ba520c> in <module>
# ----> 1 plt.legend(ax2)
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\pyplot.py in legend(*args, **kwargs)
#    2705 @docstring.copy_dedent(Axes.legend)
#    2706 def legend(*args, **kwargs):
# -> 2707     return gca().legend(*args, **kwargs)
#    2708
#    2709
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\axes\_axes.py in legend(self, *args, **kwargs)
#     418                 [self],
#     419                 *args,
# --> 420                 **kwargs)
#     421         if len(extra_args):
#     422             raise TypeError('legend only accepts two non-keyword arguments')
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\legend.py in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1294         # Get as many handles as there are labels.
# ...

# %%
fg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-61ff6a34af84> in <module>
# ----> 1 fg
#
# NameError: name 'fg' is not defined

# %%
fig

# %%
from datetime import datetime

# %%
fig2 = plt.figure()
ax = fig2.add_subplot(1,1,1)

# %%
import pandas as pd
# Out:
# D:\Software\Anaconda\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
data = pd.read_csv('examples/spx.csv',index_col=0,parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax,style='k-')

# %%
crisis_data=[(datetime(2007,10,11),'Peak of bull market'),
             (datetime(2008,3,12),'Bear Stearns Fails'),
             (datetime(2008,9,15),'Lehman Bankruptcy')]

# %%
for date,label in crises_data:
    ax.annotate(label,xy=(date,spx.asof(date)+75),
               xytext=(date,spx.asof(date)+225),
               arrowprops = dict(facecolor='black',headwidth=4,width=2,headlength=4),
               horizontalalignment='left',verticalalignment='top')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-77f61df4d127> in <module>
# ----> 1 for date,label in crises_data:
#       2     ax.annotate(label,xy=(date,spx.asof(date)+75),
#       3                xytext=(date,spx.asof(date)+225),
#       4                arrowprops = dict(facecolor='black',headwidth=4,width=2,headlength=4),
#       5                horizontalalignment='left',verticalalignment='top')
#
# NameError: name 'crises_data' is not defined

# %%
for date,label in crisis_data:
    ax.annotate(label,xy=(date,spx.asof(date)+75),
               xytext=(date,spx.asof(date)+225),
               arrowprops = dict(facecolor='black',headwidth=4,width=2,headlength=4),
               horizontalalignment='left',verticalalignment='top')

# %%
ax.set_xlim(['1/1/2007','1/1/2011'])
ax.set_ylim([600,1800])
ax.set_title('Important dates in the 2008-2009 finanacial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 finanacial crisis')

# %%
fig2

# %%
fig3 = plt.figure()
ax= fig3.add_subplot(1,1,1)

# %%
rect = plt.Rectangle((0.2,0.75),0.4,0.15,color='k',alpha=0.3)
circ = plt.Circle((0.7,0,2),0.15,color='b',alpha=0.3)
pgon=plt.Polygon([[0.15,0.15],[0.35,0.4],[0.2,0.6]],color='g',alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %%
fig3

# %%
plt.savefig('figpath.svg')

# %%
plt.rc('figure',figsize=(10,10))

# %%
fig

# %%
fig3

# %%
font_optipons = {'family':'monospace',
                 'weight':'bold',
                 'size':'small'}
plt.rc('font',**font_optipons)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\matplotlib\rcsetup.py in validate_float(s)
#     146     try:
# --> 147         return float(s)
#     148     except ValueError:
#
# ValueError: could not convert string to float: 'small'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# D:\Software\Anaconda\lib\site-packages\matplotlib\__init__.py in __setitem__(self, key, val)
#     860             try:
# --> 861                 cval = self.validate[key](val)
#     862             except ValueError as ve:
#
# D:\Software\Anaconda\lib\site-packages\matplotlib\rcsetup.py in validate_float(s)
#     148     except ValueError:
# --> 149         raise ValueError('Could not convert "%s" to float' % s)
# ...

# %%
font_optipons = {'family':'monospace',
                 'weight':'bold',
                 'size':10}
plt.rc('font',**font_optipons)

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'D:\\Software\\Anaconda\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
fig3

# %%
s = pd.Series(np.random.randn(10).cumsum(),
             index=np.arange(0,100,10))
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10.4).cumsum(0),
                  columns=['A','B','C','D'],
                  index = np.arange(0,100,10))
df.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-eff808e0c617> in <module>
# ----> 1 df = pd.DataFrame(np.random.randn(10.4).cumsum(0),
#       2                   columns=['A','B','C','D'],
#       3                   index = np.arange(0,100,10))
#       4 df.plot()
#
# mtrand.pyx in mtrand.RandomState.randn()
#
# mtrand.pyx in mtrand.RandomState.standard_normal()
#
# mtrand.pyx in mtrand.cont0_array()
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(0),
                  columns=['A','B','C','D'],
                  index = np.arange(0,100,10))
df.plot()

# %%
fig,axes=plt.subplots(2,1)
data = pd.Series(np.random.rand(6),index=list('abcdefghijklmnop'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-be5e190fc15c> in <module>
#       1 fig,axes=plt.subplots(2,1)
# ----> 2 data = pd.Series(np.random.rand(6),index=list('abcdefghijklmnop'))
#
# D:\Software\Anaconda\lib\site-packages\pandas\core\series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     247                             'Length of passed values is {val}, '
#     248                             'index implies {ind}'
# --> 249                             .format(val=len(data), ind=len(index)))
#     250                 except TypeError:
#     251                     pass
#
# ValueError: Length of passed values is 6, index implies 16

# %%
fig,axes=plt.subplots(2,1)
data = pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0],color='k',alpha=0.7)
data.plot.barh(ax=axes[1],color='k',alpha=0.7)

# %%
df = pd.DataFrame(np.random.rand(6,4),
                  index=['one','two','three','four','five','six'],
                  columns=pd.Index(['A','B','C','D'],name='Genus'))
df
# Out:
# Genus         A         B         C         D
# one    0.002958  0.391357  0.891224  0.231355
# two    0.758487  0.620484  0.047001  0.775471
# three  0.494374  0.319144  0.876578  0.662495
# four   0.417903  0.039106  0.609926  0.291087
# five   0.108554  0.188165  0.972492  0.982690
# six    0.822787  0.361592  0.294557  0.427494

# %%
df.plot.bar()

# %%
df.plot.barh(stacked=True,alpha=0.5)

# %%
tips = pd.read_csv('examples/tips.csv')
party_counts = pd.crosstab(tips['day'],tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
party_counts = party_counts.loc[:,2:5]

# %%
party_pcts = party_counts.div(party_counts.sum(1),axis=0)
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
party_pcts.plot.bar()

# %%
import seaborn as sns
# Out:
# D:\Software\Anaconda\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# D:\Software\Anaconda\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# D:\Software\Anaconda\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# D:\Software\Anaconda\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
tips['tip_pct'] = tips['tip']/(tips['total_bill']-tips['tip'])

# %%
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
sns.barplot(x='tip_pct',y='day',data=tips,orient='h')

# %%
sns.barplot(x='tip_pct',y='dat',hue='time',data=tips,orient='h')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-697fca6e97b8> in <module>
# ----> 1 sns.barplot(x='tip_pct',y='dat',hue='time',data=tips,orient='h')
#
# D:\Software\Anaconda\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# D:\Software\Anaconda\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
sns.barplot(x='tip_pct',y='day',hue='time',data=tips,orient='h')

# %%
tips['tip_pct'].plot.hist(bins=50)

# %%
tips['tip_pct'].plot.density()

# %%
comp1 = np.random.normal(0,1,size=200)
comp2=np.randm.normal(0,2,size=200)
values = pd.Series(np.concatenate([comp1,comp2]))
sns.distplot(values,bins=100,color='k')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-92-1fdc6da59192> in <module>
#       1 comp1 = np.random.normal(0,1,size=200)
# ----> 2 comp2=np.randm.normal(0,2,size=200)
#       3 values = pd.Series(np.concatenate([comp1,comp2]))
#       4 sns.distplot(values,bins=100,color='k')
#
# AttributeError: module 'numpy' has no attribute 'randm'

# %%
comp1 = np.random.normal(0,1,size=200)
comp2=np.random.normal(0,2,size=200)
values = pd.Series(np.concatenate([comp1,comp2]))
sns.distplot(values,bins=100,color='k')

# %%
comp1 = np.random.normal(0,1,size=200)
comp2=np.random.normal(10,2,size=200)
values = pd.Series(np.concatenate([comp1,comp2]))
sns.distplot(values,bins=100,color='k')

# %%
macro = pd.read_csv('examples/macrodata.csv')
data = macro[['cpi','m1','tbilrate','unemp']]
trans_data=np.log(data).diff().dropna()
trans_data[-5:]
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
sns.regplot('m1','unemp',data=trans_data)
plt.title('changes in log %s versus log %s' % ('m1','unemp'))
# Out:
# Text(0.5, 1.0, 'changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data,diag_kind='kde',plot_kws={'alpha':0.2})

# %%
sns.factorplot(x='day',y='tip_pct',hue='time',col='smoker',kind='bar'
               ,data=tips[tips.tip_pct < 1])
# Out:
# D:\Software\Anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day',y='tip_pct',row='time',col='smoker',
               kind='bar',data=tips[tips.tip_pct<1])
# Out:
# D:\Software\Anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='tip_pct',y='day',kind='box',
               data=tips[ips.tip_pct<0.5])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-100-d4b07a8fd965> in <module>
#       1 sns.factorplot(x='tip_pct',y='day',kind='box',
# ----> 2                data=tips[ips.tip_pct<0.5])
#
# NameError: name 'ips' is not defined

# %%
sns.factorplot(x='tip_pct',y='day',kind='box',
               data=tips[tips.tip_pct<0.5])
# Out:
# D:\Software\Anaconda\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
